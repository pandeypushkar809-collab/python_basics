# %% [markdown]
# # Numeric datatypes
#
# * int
# * float
# * complex

# %%
# Variable assinged with float value
pi = 3.14
radius = 5
# Variable assinged to integer value
# Calculate area with standard formula
area = pi * radius * radius
# printing the area 
area
# Out:
# 78.5

# %%
type(pi)
# Out:
# float

# %%
type(radius)
# Out:
# int

# %%
type(area)
# Out:
# float

# %%
# type hint
pi: float = 3.14
radius : float = 5
area : float = pi * radius * radius

# %%
# Arthematic operators
maths : int = 97
science : int = 81
social : int = 83

# %%
marks: int = maths + science + social 
marks
# Out:
# 261

# %%
# average 
marks / 300 * 100
# Out:
# 87.0

# %%
pi * radius ** 2
# Out:
# 78.5

# %%
number: int = 17
number % 2
               # IF IT IS ONE IT IS A ODD  NUMBER
# Out:
# 1

# %%
number: int = 18
number % 2
# IF IT IS ZERO IT IS A EVEN NUMBER
# Out:
# 0

# %%
4 // 3
# Out:
# 1

# %%
4 / 3
# Out:
# 1.3333333333333333

# %%
# Assingment operators 

x = 5    
y = x 
z = y +1 
print(x)
print(y)
z
# Out:
# 5
# 5
# 6

# %%
n = 5 
n = n + 1
n
# Out:
# 6

# %%
n = 5
n += 1
n
# Out:
# 6

# %%
n = 17 
n % 2 == 0
# Out:
# False

# %%
n = 10
n % 2 == 0
# Out:
# True

# %%
n = 18 
n % 2 == 0
# Out:
# True

# %%
 # X is greater then 5 and X is even 
X = 4
type(4)

X > 5 and X % 2 == 0
# Out:
# False

# %%
X = 4
X > 5 or  X % 2 == 0
 # OR means if one is true then true.
# Out:
# True

# %%
# multiple of 3 or 5 
number = int(input("Enter any numbet"))
number % 3 == 0 or number % 5 == 0
# Out:
# True

# %%
# Calculate 
# Simple intrest
# compound intrest
# Convert kilogram into pounds 
# Convert yards into feet

# %%
# Simpel intrest 

p = 30
r = 7
t = 6 
si = (p * r * t) / 100
print(si)
# Out:
# 12

# %%
P = int(input("Enter number"))
R = int(input("enter number"))
T = int(input("Enter number"))
SI = (P * R * T) / 100
print(SI)
# Out:
# 0

# %%
# Compound intrest 


P = int(input("Enter number")) 
r = int(input("Enter number")) 
n = int(input("Enter number")) 
t = int(input("Enter number")) 
A = P *1 + r/n* n*t
print(A)
# Out:
# 6

# %%
# Convert kilogram into pounds
#  
kg = int(input("Enter weight in kilograms: "))
pounds = kg *  (2.20462)
print(pounds)
# Out:
# 121

# %%
# Convert yards into feet 

yards = int(input("Enter length in yards: "))
feet = yards * 3
print(feet)
# Out:
# 60

# %%
X = 3 * 5 + 6 // 8 - 7 * 10 + 100

# %%
X = 3 * (5 + 6) // 8 - (7 * 10 + 100)
